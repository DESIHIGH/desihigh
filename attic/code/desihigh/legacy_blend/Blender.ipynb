# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# # A lightning fast introduction to Blender

# %% [markdown]
# This notebook remains largely unsupported for now, but potentially a fun intro to 3D rendering with Blender and the Legacy Survey.  Blender is a free, open source program capable of:

# %%
YouTubeVideo('WhWc3b3KhnY')

# %% [markdown]
# with (a lot) of patience and python.  There are many introductions out there.  To get a copy of Blender, you'll want to visit https://www.blender.org/.

# %% [markdown]
# <img src="images/BlenderDownload.png" alt="Drawing" style="width: 800px;"/>

# %% [markdown]
# and follow the download instructions for your operating system.  The official Blender introduction to scripting is

# %%
YouTubeVideo('https://www.youtube.com/watch?v=opZy2OJp8co&list=PLa1F2ddGya_8acrgoQr1fTeIuQtkSd6BW')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=opZy2OJp8co&list=PLa1F2ddGya_8acrgoQr1fTeIuQtkSd6BW"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# but K12 specific intros. are out there.

# %% [markdown]
# Blender is responsible for the relative ease with which its possible to create a fly-through of the Legacy Survey shown in RipplesInTheCosmos.ipynb.

# %% [markdown]
# If you were interested in developing this further, you might reproduce the text within legacy_blend.bpy in the scripting window of a new Blender scene.  Be warned, it's a steep learning curve at the start!
